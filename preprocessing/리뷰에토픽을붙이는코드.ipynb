# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df_reviews = pd.read_excel('/content/drive/Shareddrives/[논문] 내 외국인관광객 유동인구 비교/분석/전처리/명소_외국인_이름정리.xlsx')
df_sites = pd.read_excel('/content/drive/Shareddrives/[논문] 내 외국인관광객 유동인구 비교/분석/분석/LDA/LDA결과/넷마이너_명소_분석_결과(01_28_13시).xlsx')

# %%
df_sites.head()
# Out:
#    Unnamed: 0          name  ...         lng   Topic
# 0           0    2.28기념중앙공원  ...  128.597778  Topic6
# 1           1  2.28민주운동기념회관  ...  128.589620  Topic3
# 2           2     3.1만세운동계단  ...  128.586041  Topic3
# 3           3         83 타워  ...  128.563417  Topic4
# 4           4           강정보  ...  128.460782  Topic6
#
# [5 rows x 6 columns]

# %%
topicList = list()
for i in range(0, df_reviews.shape[0]):
  topicList.append(df_sites[df_sites['name']==df_reviews.loc[i, 'name']]['Topic'].tolist()[0])

# %%
df_fin = df_reviews
df_fin['Topic'] = topicList

# %%
df_fin.head()
# Out:
#   name       date  ... foreigner   Topic
# 0  아양교  1921.1.18  ...         1  Topic6
# 1  아양교  1921.1.18  ...         1  Topic6
# 2  아양교  1921.1.18  ...         1  Topic6
# 3  아양교  1921.1.18  ...         1  Topic6
# 4  아양교  1921.1.18  ...         1  Topic6
#
# [5 rows x 10 columns]

# %%
df_fin.to_excel('/content/drive/Shareddrives/[논문] 내 외국인관광객 유동인구 비교/분석/분석/LDA/LDA결과/넷마이너_명소_분석_결과(01_28_13시)_리뷰별.xlsx')
